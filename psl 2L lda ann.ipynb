# %%
##########      train      ###########
import pandas as pd
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

# %%
#tain data 전처리
data=pd.read_excel('C:/Users/user/Desktop/psl/fault_feature 1000 2L.xls')

X_tn=data.drop(['target','type','m'], axis=1)
y_tn=data.filter(['target'])
z_tn=data.filter(['type'])

X_ac_tn=X_tn.filter(['VA_am','VA_aph','IA_am','IA_aph','VB_am','VB_aph','IB_am','IB_aph','VA_cm','VA_cph','IA_cm','IA_cph','VB_cm','VB_cph','IB_cm','IB_cph'])

row_tn=y_tn.shape[0]
yy_tn=y_tn.to_numpy()
z_tn=z_tn.to_numpy()
    
for i in range(0,row_tn-1):
    if z_tn[i]==4:
        yy_tn[i]=0
    elif z_tn[i]==5:
        yy_tn[i]=0
    elif z_tn[i]==6:
        yy_tn[i]=yy_tn[i]
    else:
        yy_tn[i]=0
        
yy_tn=pd.DataFrame(yy_tn)
print(yy_tn.shape)
# Out:
# (1000, 1)

# %%
#train data lda
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis(n_components = 3)
lda6 = lda.fit(X_ac_tn,yy_tn)

Xac_lda_tn=lda6.transform(X_ac_tn)

print(Xac_lda_tn.shape)

print(lda.explained_variance_ratio_)
# Out:
# (1000, 3)
# [0.59306221 0.38590874 0.01944858]
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#lda train plot
lda_columns = ['lda_comp1', 'lda_comp2','lda_comp3']
Xac_lda_df = pd.DataFrame(Xac_lda_tn, columns=lda_columns)
Xac_lda_df['target'] = yy_tn

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

df = Xac_lda_df
markers = ['o','.','X','s','D','v','^']

for i, mark in enumerate(markers):
    df_i = df[df['target']== i]
    type_i = i
    X1 = df_i['lda_comp1']
    X2 = df_i['lda_comp2']
    X3 = df_i['lda_comp3']
    ax.scatter(X1, X2, X3,
                marker=mark,
                label=type_i)

ax.set_xlabel('lda_component1')
ax.set_ylabel('lda_component2')
ax.set_zlabel('lda_component3')
ax.legend(loc='best')
plt.savefig('test.png')
plt.show()

# %%
##########      ANN train      ###########
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import load_model
from keras.utils import to_categorical

# %%
keras.utils.set_random_seed(1)
model = Sequential()   
yyy_tn=to_categorical(yy_tn)

# %%
# Adding the input layer and first hidden layer
model.add(Dense(32, kernel_initializer='he_normal', activation = 'leaky_relu', input_dim = 3))
# Adding the second hidden layer
model.add(Dense(64, kernel_initializer='he_normal', activation = 'leaky_relu'))
# Adding the output layer
model.add(Dense(7, kernel_initializer='he_normal', activation = 'softmax'))

model.summary()

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Fitting the ANN to the Training set

epoch=150
results=model.fit(Xac_lda_tn, yyy_tn, batch_size = 10, epochs = epoch, validation_split = 0.2)

result=np.array(results.history['val_accuracy'])
acc=np.array(results.history['accuracy'])

for i in range(epoch):
    if result[i] > result[i-1]:
        model.save('C:/Python/hj_learning_ac.h5')
    else:
        pass
        
print('Max of acc: ',max(results.history['accuracy']))
print('Max of Val_acc: ',max(results.history['val_accuracy']))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                128
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 2,695
# Trainable params: 2,695
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 1s 4ms/step - loss: 1.8588 - accuracy: 0.7175 - val_loss: 0.1765 - val_accuracy: 0.9700
# Epoch 2/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9625 - val_loss: 0.1136 - val_accuracy: 0.9650
# Epoch 3/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0881 - accuracy: 0.9800 - val_loss: 0.0964 - val_accuracy: 0.9550
# Epoch 4/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9837 - val_loss: 0.0864 - val_accuracy: 0.9750
# Epoch 5/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9850 - val_loss: 0.0706 - val_accuracy: 0.9700
# Epoch 6/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9787 - val_loss: 0.0647 - val_accuracy: 0.9750
# Epoch 7/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9850 - val_loss: 0.0640 - val_accuracy: 0.9750
# Epoch 8/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9850 - val_loss: 0.0540 - val_accuracy: 0.9850
# Epoch 9/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9850 - val_loss: 0.0565 - val_accuracy: 0.9650
# Epoch 10/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9875 - val_loss: 0.0491 - val_accuracy: 0.9900
# Epoch 11/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9850 - val_loss: 0.0802 - val_accuracy: 0.9700
# Epoch 12/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9900 - val_loss: 0.1180 - val_accuracy: 0.9600
# Epoch 13/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9800 - val_loss: 0.0562 - val_accuracy: 0.9750
# Epoch 14/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 0.0489 - val_accuracy: 0.9800
# Epoch 15/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9887 - val_loss: 0.0874 - val_accuracy: 0.9750
# Epoch 16/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9875 - val_loss: 0.0589 - val_accuracy: 0.9750
# Epoch 17/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9875 - val_loss: 0.0583 - val_accuracy: 0.9650
# Epoch 18/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9887 - val_loss: 0.0730 - val_accuracy: 0.9650
# Epoch 19/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9912 - val_loss: 0.1163 - val_accuracy: 0.9600
# Epoch 20/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9850 - val_loss: 0.0605 - val_accuracy: 0.9650
# Epoch 21/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 0.9837 - val_loss: 0.0538 - val_accuracy: 0.9750
# Epoch 22/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.0461 - val_accuracy: 0.9900
# Epoch 23/150
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9862 - val_loss: 0.0791 - val_accuracy: 0.9650
# Epoch 24/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9862 - val_loss: 0.0529 - val_accuracy: 0.9750
# Epoch 25/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9887 - val_loss: 0.0414 - val_accuracy: 0.9900
# Epoch 26/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9900 - val_loss: 0.0424 - val_accuracy: 0.9950
# Epoch 27/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9887 - val_loss: 0.0894 - val_accuracy: 0.9800
# Epoch 28/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9862 - val_loss: 0.1134 - val_accuracy: 0.9700
# Epoch 29/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9850 - val_loss: 0.0501 - val_accuracy: 0.9850
# Epoch 30/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.0762 - val_accuracy: 0.9800
# Epoch 31/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9887 - val_loss: 0.0771 - val_accuracy: 0.9750
# Epoch 32/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9862 - val_loss: 0.0926 - val_accuracy: 0.9800
# Epoch 33/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.0514 - val_accuracy: 0.9850
# Epoch 34/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9950 - val_loss: 0.0699 - val_accuracy: 0.9800
# Epoch 35/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9862 - val_loss: 0.0546 - val_accuracy: 0.9750
# Epoch 36/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9875 - val_loss: 0.0640 - val_accuracy: 0.9800
# Epoch 37/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9887 - val_loss: 0.0556 - val_accuracy: 0.9650
# Epoch 38/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9887 - val_loss: 0.0622 - val_accuracy: 0.9700
# Epoch 39/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.0759 - val_accuracy: 0.9650
# Epoch 40/150
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 0.9887 - val_loss: 0.1024 - val_accuracy: 0.9700
# Epoch 41/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.1327 - val_accuracy: 0.9600
# Epoch 42/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0452 - accuracy: 0.9850 - val_loss: 0.0731 - val_accuracy: 0.9850
# Epoch 43/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9962 - val_loss: 0.0525 - val_accuracy: 0.9750
# Epoch 44/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9837 - val_loss: 0.1087 - val_accuracy: 0.9700
# Epoch 45/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9837 - val_loss: 0.0679 - val_accuracy: 0.9850
# Epoch 46/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9925 - val_loss: 0.0693 - val_accuracy: 0.9850
# Epoch 47/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9887 - val_loss: 0.0805 - val_accuracy: 0.9800
# Epoch 48/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9875 - val_loss: 0.0510 - val_accuracy: 0.9900
# Epoch 49/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9900 - val_loss: 0.0640 - val_accuracy: 0.9850
# Epoch 50/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9925 - val_loss: 0.0433 - val_accuracy: 0.9950
# Epoch 51/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9912 - val_loss: 0.0574 - val_accuracy: 0.9850
# Epoch 52/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9862 - val_loss: 0.0885 - val_accuracy: 0.9800
# Epoch 53/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9925 - val_loss: 0.0445 - val_accuracy: 0.9850
# Epoch 110/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0499 - val_accuracy: 0.9900
# Epoch 111/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9912 - val_loss: 0.0425 - val_accuracy: 0.9950
# Epoch 112/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9937 - val_loss: 0.0494 - val_accuracy: 0.9750
# Epoch 113/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0458 - val_accuracy: 0.9950
# Epoch 114/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 0.0556 - val_accuracy: 0.9900
# Epoch 115/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9912 - val_loss: 0.0568 - val_accuracy: 0.9900
# Epoch 116/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 0.0595 - val_accuracy: 0.9900
# Epoch 117/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0475 - val_accuracy: 0.9950
# Epoch 118/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9937 - val_loss: 0.0428 - val_accuracy: 0.9950
# Epoch 119/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0756 - val_accuracy: 0.9850
# Epoch 120/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9912 - val_loss: 0.0586 - val_accuracy: 0.9900
# Epoch 121/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0518 - val_accuracy: 0.9900
# Epoch 122/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9925 - val_loss: 0.0398 - val_accuracy: 0.9950
# Epoch 123/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9900 - val_loss: 0.0529 - val_accuracy: 0.9900
# Epoch 124/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9900 - val_loss: 0.0468 - val_accuracy: 0.9900
# Epoch 125/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0492 - val_accuracy: 0.9900
# Epoch 126/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0509 - val_accuracy: 0.9900
# Epoch 127/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.0473 - val_accuracy: 0.9950
# Epoch 128/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0452 - val_accuracy: 0.9950
# Epoch 129/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 0.9975 - val_loss: 0.0429 - val_accuracy: 0.9950
# Epoch 130/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9937 - val_loss: 0.0450 - val_accuracy: 0.9750
# Epoch 131/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0463 - val_accuracy: 0.9900
# Epoch 132/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9950 - val_loss: 0.0459 - val_accuracy: 0.9950
# Epoch 133/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9925 - val_loss: 0.0494 - val_accuracy: 0.9900
# Epoch 134/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0458 - val_accuracy: 0.9950
# Epoch 135/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0586 - val_accuracy: 0.9900
# Epoch 136/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.0479 - val_accuracy: 0.9900
# Epoch 137/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9925 - val_loss: 0.0841 - val_accuracy: 0.9800
# Epoch 138/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9937 - val_loss: 0.0412 - val_accuracy: 0.9950
# Epoch 139/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.0561 - val_accuracy: 0.9900
# Epoch 140/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9925 - val_loss: 0.0633 - val_accuracy: 0.9900
# Epoch 141/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.0545 - val_accuracy: 0.9900
# Epoch 142/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9937 - val_loss: 0.0505 - val_accuracy: 0.9900
# Epoch 143/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0451 - val_accuracy: 0.9800
# Epoch 144/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9912 - val_loss: 0.0457 - val_accuracy: 0.9950
# Epoch 145/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.0622 - val_accuracy: 0.9900
# Epoch 146/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 0.0412 - val_accuracy: 0.9950
# Epoch 147/150
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9937 - val_loss: 0.0647 - val_accuracy: 0.9850
# Epoch 148/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0462 - val_accuracy: 0.9900
# Epoch 149/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9937 - val_loss: 0.0408 - val_accuracy: 0.9900
# Epoch 150/150
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9925 - val_loss: 0.0505 - val_accuracy: 0.9750
# Max of acc:  0.9987499713897705
# Max of Val_acc:  0.9950000047683716

# %%
#train/validation acc plot
plt.plot(results.history['val_accuracy'])
plt.plot(results.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['val_acc', 'acc'], loc='lower right')
plt.savefig('test.png')
plt.show()

# %%
##########      test      ###########
#test data 전처리
data_te=pd.read_excel('C:/Users/user/Desktop/psl/fault_feature_100 2L.xls')
X=data_te.drop(['target','type','m'],axis=1)
y=data_te.filter(['target'])
z=data_te.filter(['type'])

X_ac=X.filter(['VA_am','VA_aph','IA_am','IA_aph','VB_am','VB_aph','IB_am','IB_aph','VA_cm','VA_cph','IA_cm','IA_cph','VB_cm','VB_cph','IB_cm','IB_cph'])

row=y.shape[0]
yy=y.to_numpy()
z=z.to_numpy()

yy_ac=np.zeros((row,1))
    
for i in range(0,row-1):
    if z[i]==4:
        yy_ac[i]=0
    elif z[i]==5:
        yy_ac[i]=0
    elif z[i]==6:
        yy_ac[i]=yy[i]
    else:
        yy_ac[i]=0
        
yy_ac=pd.DataFrame(yy_ac)

# %%
#test data lda
Xac_lda=lda6.transform(X_ac)
Xac_lda_df = pd.DataFrame(Xac_lda)
yyy_ac=to_categorical(yy_ac)

# %%
#model test
modelac = load_model("hj_learning_ac.h5")

modelac.evaluate(Xac_lda, yyy_ac, batch_size = 1)
pred_ac = modelac.predict(Xac_lda, batch_size = 1)
# Out:
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# 100/100 [==============================] - 0s 842us/step
